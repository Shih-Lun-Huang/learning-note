# %% [markdown]
# 機器學習競賽是提高數據科學技能和進步的好方法。
#
# 在下一個練習中，您將為[給Kaggle Learn用戶的房價競賽](https://www.kaggle.com/c/home-data-for-ml-course)創建並提交預測的結果。

# %%
from IPython.display import Image

# %%
Image(filename = "img/L2-7.png", width = 600, height = 300)
