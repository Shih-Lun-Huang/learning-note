# %% [markdown]
# ### 歡迎來到Kaggle Learn的中級機器學習微課程！
#
# 如果您具有一定的機器學習背景，並且想學習如何快速提高模型質量，那麼您來對地方了！在本微型課程中，將通過學習以下方法來加速機器學習的專業知識：
#
# - 處理通常在現實世界數據集中發現的數據類型 **（缺失值(missing values) ** ，** 分類變量(categorical variables) ** ），
# - 設計  **pipelines** 以提高機器學習代碼的質量，
# - 使用高級技術進行模型驗證**（交叉驗證(cross-validation)）**，
# - 建立廣泛用於贏得Kaggle競賽（**XGBoost**）的最新模型(state-of-the-art models)，以及
# - 避免常見和重要的數據科學錯誤（**遺漏**）。
#
# 在此過程中，您將通過針對每個新主題的真實數據完成動手練習來鞏固自己的知識。動手練習使用來自[Kaggle Learn用戶住房價格競賽](https://www.kaggle.com/c/home-data-for-ml-course)的數據，您將在其中使用79個不同的解釋變量（例如屋頂類型，臥室數量和浴室數量）來預測房價。透過本次比賽提交預測並觀察自己在排行榜上的排名來衡量自己的進步！

# %%
from IPython.display import Image 
Image(filename = "img/L3-1.png")

# %% [markdown]
# ## 先決條件
#
# 如果您之前已經建立了機器學習模型，那麼您已經準備好參加此微課程，並且熟悉諸如[模型驗證](https://www.kaggle.com/dansbecker/model-validation)，[欠擬合和過擬合](https://www.kaggle.com/dansbecker/underfitting-and-overfitting)以及[隨機森林](https://www.kaggle.com/dansbecker/random-forests)之類的主題。
#
# 如果您是機器學習的新手，請查看我們的[入門級微課程](https://www.kaggle.com/learn/intro-to-machine-learning)，其中涵蓋了準備該中級微課程所需的一切。
